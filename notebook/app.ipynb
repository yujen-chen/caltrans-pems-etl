# %%
# read processed parquet data
import pandas as pd
import warnings
warnings.filterwarnings('ignore')


processed_data_path = "../data/processed/2021_station_hour_processed.parquet"
df = pd.read_parquet(processed_data_path)
df.tail()
# Out:
#         station  district  route direction type  hour   month  lanes  length  \
# 243498  1222038        12      5         S   HV    19  August      2    0.43
# 243499  1222038        12      5         S   HV    20  August      2    0.43
# 243500  1222038        12      5         S   HV    21  August      2    0.43
# 243501  1222038        12      5         S   HV    22  August      2    0.43
# 243502  1222038        12      5         S   HV    23  August      2    0.43
#
#         median_flow  ...  sd_speed  median_occup  avg_occup  sd_occup  \
# 243498        834.0  ...  1.739474        0.0496   0.049592  0.005422
# 243499        670.0  ...  1.128023        0.0403   0.040492  0.007753
# 243500        542.0  ...  0.511283        0.0320   0.032785  0.007270
# 243501        394.0  ...  0.773686        0.0227   0.023969  0.006703
# 243502        182.0  ...  0.290446        0.0105   0.011423  0.003329
#
#         days_observed  county  state_pm  abs_pm  latitude  longitude
# 243498             13      59      13.7  85.895    33.558   -117.673
# 243499             13      59      13.7  85.895    33.558   -117.673
# 243500             13      59      13.7  85.895    33.558   -117.673
# 243501             13      59      13.7  85.895    33.558   -117.673
# 243502             13      59      13.7  85.895    33.558   -117.673
#
# [5 rows x 24 columns]

# %%
# !uv pip install plotly folium
# Out:
# Using Python 3.11.8 environment at: /Users/yu-jenchen/workspace/Projects/caltrans-pems-etl/.venv
# Resolved 14 packages in 235ms
# ⠙ Preparing packages... (0/8)
# ⠙ Preparing packages... (0/8)--------------     0 B/63.22 KiB
# ⠙ Preparing packages... (0/8)--------------     0 B/63.22 KiB
# requests             ------------------------------     0 B/63.22 KiB
# ⠙ Preparing packages... (0/8)--------------     0 B/131.74 KiB
# requests             ------------------------------     0 B/63.22 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/131.74 KiB
# requests             ------------------------------     0 B/63.22 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/131.74 KiB
# requests             ------------------------------     0 B/63.22 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/131.74 KiB
# requests             ------------------------------     0 B/63.22 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# ⠙ Preparing packages... (0/8)--------------     0 B/391.62 KiB
# requests             ------------------------------     0 B/63.22 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/391.62 KiB
# requests             ------------------------------ 16.00 KiB/63.22 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/391.62 KiB
# requests             ------------------------------ 32.00 KiB/63.22 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/391.62 KiB
# requests             ------------------------------ 48.00 KiB/63.22 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/391.62 KiB
# requests             ------------------------------ 63.22 KiB/63.22 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/391.62 KiB
# requests             ------------------------------ 63.22 KiB/63.22 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/391.62 KiB
# requests             ------------------------------ 63.22 KiB/63.22 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/391.62 KiB
# requests             ------------------------------ 63.22 KiB/63.22 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/391.62 KiB
# requests             ------------------------------ 63.22 KiB/63.22 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/391.62 KiB
# markupsafe           ------------------------------     0 B/12.10 KiB
# requests             ------------------------------ 63.22 KiB/63.22 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/391.62 KiB
# markupsafe           ------------------------------ 12.10 KiB/12.10 KiB
# branca               ------------------------------     0 B/25.46 KiB
# xyzservices          ------------------------------     0 B/88.27 KiB
# folium               ------------------------------     0 B/110.74 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# narwhals             ------------------------------ 14.88 KiB/391.62 KiB
# ⠙ Preparing packages... (0/8)--------------     0 B/9.34 MiB
# branca               ------------------------------     0 B/25.46 KiB
# xyzservices          ------------------------------     0 B/88.27 KiB
# folium               ------------------------------     0 B/110.74 KiB
# jinja2               ------------------------------ 14.88 KiB/131.74 KiB
# narwhals             ------------------------------ 14.88 KiB/391.62 KiB
# ⠙ Preparing packages... (0/8)--------------     0 B/9.34 MiB
# branca               ------------------------------ 14.91 KiB/25.46 KiB
# xyzservices          ------------------------------ 14.91 KiB/88.27 KiB
# folium               ------------------------------ 14.88 KiB/110.74 KiB
# jinja2               ------------------------------ 30.88 KiB/131.74 KiB
# narwhals             ------------------------------ 30.88 KiB/391.62 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/9.34 MiB
# xyzservices          ------------------------------ 14.91 KiB/88.27 KiB
# folium               ------------------------------ 14.88 KiB/110.74 KiB
# jinja2               ------------------------------ 62.88 KiB/131.74 KiB
# narwhals             ------------------------------ 52.65 KiB/391.62 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/9.34 MiB
# xyzservices          ------------------------------ 78.91 KiB/88.27 KiB
# folium               ------------------------------ 78.88 KiB/110.74 KiB
# narwhals             ------------------------------ 93.44 KiB/391.62 KiB
# ⠙ Preparing packages... (0/8)-------------- 78.91 KiB/9.34 MiB
# xyzservices          ------------------------------ 88.27 KiB/88.27 KiB
# folium               ------------------------------ 94.88 KiB/110.74 KiB
# narwhals             ------------------------------ 132.90 KiB/391.62 KiB
# ⠙ Preparing packages... (0/8)-------------- 142.91 KiB/9.34 MiB
# folium               ------------------------------ 94.88 KiB/110.74 KiB
# narwhals             ------------------------------ 141.44 KiB/391.62 KiB
# ⠙ Preparing packages... (0/8)-------------- 142.91 KiB/9.34 MiB
# narwhals             ------------------------------ 173.44 KiB/391.62 KiB
# ⠙ Preparing packages... (0/8)-------------- 158.91 KiB/9.34 MiB
# ⠙ Preparing packages... (0/8)-------------- 462.91 KiB/9.34 MiB
# ⠙ Preparing packages... (0/8)-------------- 1.11 MiB/9.34 MiB
# ⠹ Preparing packages... (7/8)-------------- 1.95 MiB/9.34 MiB
# ⠹ Preparing packages... (7/8)-------------- 2.72 MiB/9.34 MiB
# ⠹ Preparing packages... (7/8)-------------- 4.72 MiB/9.34 MiB
# ⠸ Preparing packages... (7/8)---------- 6.34 MiB/9.34 MiB
# ⠸ Preparing packages... (7/8)---------- 6.60 MiB/9.34 MiB
# Prepared 8 packages in 481ms
# Installed 12 packages in 24ms
#  + branca==0.8.1
#  + certifi==2025.8.3
#  + charset-normalizer==3.4.3
#  + folium==0.20.0
#  + idna==3.10
#  + jinja2==3.1.6
#  + markupsafe==3.0.2
#  + narwhals==2.2.0
#  + plotly==6.3.0
#  + requests==2.32.5
#  + urllib3==2.5.0
#  + xyzservices==2025.4.0
